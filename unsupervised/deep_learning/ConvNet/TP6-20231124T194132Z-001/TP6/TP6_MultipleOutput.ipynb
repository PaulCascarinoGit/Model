# %% [markdown]
# # TP 6 - Image Classification with Convolutional Neural Networks
#
# In this assignment, you will build a ConvNet for solving an image classification problem. You will be working on a fashion/clothing dataset, where the goal is to categorize the items according to two criteria:
#
#  - **Clothing type**: Shirts, dresses, jeans, shoes.
#  - **Color**: Red, blue, black.
#
# ![clothing_dataset.jpg](attachment:clothing_dataset.jpg)
#
# You will tackle this problem in incremental steps:
#
#  1. build a **multi-class classifier**, where each pair of clothing type and color is a different class;
#
#  - build a **multi-label classifier**, where your ConvNet has a different output for each possible sub-class (shirt, dress, jeans, shoes, red, blue, black), and they can be activated simultaneously in order to predict the clothing type and color.
#
#  - build a **multi-output classifier**, where your ConvNet has two output heads, one for predicting the clothing type, and the other for predicting the color.
#
# This assignment is open-ended. Your goal is to maximize the performance of your ConvNets by using all the tricks you have learned in the course.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras import utils, layers, models, optimizers
from tensorflow.keras.preprocessing import image

from sklearn.preprocessing import LabelBinarizer, MultiLabelBinarizer

# %% [markdown]
# ## 1. Fashion Dataset
#
# The dataset consists of 2525 images across seven combinations of clothing type and color:
#
#  - Black jeans (344 images)
#  - Black shoes (358 images)
#  - Blue dress (386 images)
#  - Blue jeans (356 images)
#  - Blue shirt (369 images)
#  - Red dress (380 images)
#  - Red shirt (332 images)
#
# These images were downloaded via the Bing Image Search API. The entire process of downloading the images and manually removing the irrelevant ones for each of the seven combinations took approximately 30 minutes.

# %%
# !wget https://perso.esiee.fr/~najmanl/fashion_datasets.zip
# !unzip fashion_datasets.zip
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: fashion_dataset/black_shoes/00000201.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000201.jpg
#   inflating: fashion_dataset/black_shoes/00000017.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000017.jpg
#   inflating: fashion_dataset/black_shoes/00000003.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000003.jpg
#   inflating: fashion_dataset/black_shoes/00000188.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000188.jpg
#   inflating: fashion_dataset/black_shoes/00000283.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000283.jpeg
#   inflating: fashion_dataset/black_shoes/00000163.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000163.jpg
#   inflating: fashion_dataset/black_shoes/00000177.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000177.jpg
#   inflating: fashion_dataset/black_shoes/00000349.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000349.jpg
#   inflating: fashion_dataset/black_shoes/00000361.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000361.JPG
#   inflating: fashion_dataset/black_shoes/00000375.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000375.jpg
#   inflating: fashion_dataset/black_shoes/00000363.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000363.jpg
#   inflating: fashion_dataset/black_shoes/00000377.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000377.jpg
#   inflating: fashion_dataset/black_shoes/00000161.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000161.jpg
#   inflating: fashion_dataset/black_shoes/00000175.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000175.jpg
#   inflating: fashion_dataset/black_shoes/00000149.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000149.jpg
#   inflating: fashion_dataset/black_shoes/00000077.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000077.jpeg
#   inflating: fashion_dataset/black_shoes/00000015.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000015.jpg
#   inflating: fashion_dataset/black_shoes/00000001.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000001.jpg
#   inflating: fashion_dataset/black_shoes/00000029.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000029.JPG
#   inflating: fashion_dataset/black_shoes/00000217.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000217.JPG
#   inflating: fashion_dataset/black_shoes/00000203.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000203.jpg
#   inflating: fashion_dataset/black_shoes/00000202.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000202.jpg
#   inflating: fashion_dataset/black_shoes/00000216.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000216.jpg
#   inflating: fashion_dataset/black_shoes/00000299.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000299.jpeg
#   inflating: fashion_dataset/black_shoes/00000028.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000028.jpg
#   inflating: fashion_dataset/black_shoes/00000000.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000000.jpg
#   inflating: fashion_dataset/black_shoes/00000148.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000148.jpg
#   inflating: fashion_dataset/black_shoes/00000174.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000174.jpg
#   inflating: fashion_dataset/black_shoes/00000160.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000160.jpg
#   inflating: fashion_dataset/black_shoes/00000376.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000376.JPG
#   inflating: fashion_dataset/black_shoes/00000339.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000339.jpg
#   inflating: fashion_dataset/black_shoes/00000379.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000379.jpeg
#   inflating: fashion_dataset/black_shoes/00000305.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000305.jpg
#   inflating: fashion_dataset/black_shoes/00000311.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000311.jpg
#   inflating: fashion_dataset/black_shoes/00000107.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000107.jpg
#   inflating: fashion_dataset/black_shoes/00000113.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000113.jpg
#   inflating: fashion_dataset/black_shoes/00000098.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000098.jpg
#   inflating: fashion_dataset/black_shoes/00000265.png
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000265.png
#   inflating: fashion_dataset/black_shoes/00000259.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000259.jpg
#   inflating: fashion_dataset/black_shoes/00000271.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000271.jpg
#   inflating: fashion_dataset/black_shoes/00000067.png
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000067.png
#   inflating: fashion_dataset/black_shoes/00000046.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000046.jpeg
#   inflating: fashion_dataset/black_shoes/00000264.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000264.jpg
#   inflating: fashion_dataset/black_shoes/00000270.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000270.jpg
#   inflating: fashion_dataset/black_shoes/00000258.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000258.jpg
#   inflating: fashion_dataset/black_shoes/00000099.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000099.jpg
#   inflating: fashion_dataset/black_shoes/00000066.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000066.jpg
#   inflating: fashion_dataset/black_shoes/00000072.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000072.jpg
#   inflating: fashion_dataset/black_shoes/00000112.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000112.jpg
#   inflating: fashion_dataset/black_shoes/00000106.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000106.jpg
#   inflating: fashion_dataset/black_shoes/00000310.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000310.JPG
#   inflating: fashion_dataset/black_shoes/00000304.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000304.JPG
#   inflating: fashion_dataset/black_shoes/00000338.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000338.jpg
#   inflating: fashion_dataset/black_shoes/00000312.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000312.jpg
#   inflating: fashion_dataset/black_shoes/00000306.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000306.jpg
#   inflating: fashion_dataset/black_shoes/00000138.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000138.JPG
#   inflating: fashion_dataset/black_shoes/00000110.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000110.jpg
#   inflating: fashion_dataset/black_shoes/00000104.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000104.jpg
#   inflating: fashion_dataset/black_shoes/00000064.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000064.jpg
#   inflating: fashion_dataset/black_shoes/00000070.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000070.jpg
#   inflating: fashion_dataset/black_shoes/00000266.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000266.JPG
#   inflating: fashion_dataset/black_shoes/00000272.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000272.jpg
#   inflating: fashion_dataset/black_shoes/00000298.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000298.JPG
#   inflating: fashion_dataset/black_shoes/00000273.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000273.jpg
#   inflating: fashion_dataset/black_shoes/00000267.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000267.jpg
#   inflating: fashion_dataset/black_shoes/00000071.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000071.jpg
#   inflating: fashion_dataset/black_shoes/00000065.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000065.jpg
#   inflating: fashion_dataset/black_shoes/00000059.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000059.jpg
#   inflating: fashion_dataset/black_shoes/00000105.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000105.jpg
#   inflating: fashion_dataset/black_shoes/00000111.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000111.jpg
#   inflating: fashion_dataset/black_shoes/00000139.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000139.jpg
#   inflating: fashion_dataset/black_shoes/00000307.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000307.jpg
#   inflating: fashion_dataset/black_shoes/00000313.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000313.JPG
#   inflating: fashion_dataset/black_shoes/00000317.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000317.jpg
#   inflating: fashion_dataset/black_shoes/00000115.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000115.jpg
#   inflating: fashion_dataset/black_shoes/00000129.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000129.jpg
#   inflating: fashion_dataset/black_shoes/00000382.gif
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000382.gif
#   inflating: fashion_dataset/black_shoes/00000061.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000061.jpg
#   inflating: fashion_dataset/black_shoes/00000075.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000075.jpg
#   inflating: fashion_dataset/black_shoes/00000049.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000049.jpg
#   inflating: fashion_dataset/black_shoes/00000263.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000263.jpg
#   inflating: fashion_dataset/black_shoes/00000277.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000277.jpg
#   inflating: fashion_dataset/black_shoes/00000288.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000288.jpg
#   inflating: fashion_dataset/black_shoes/00000289.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000289.jpg
#   inflating: fashion_dataset/black_shoes/00000262.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000262.jpg
#   inflating: fashion_dataset/black_shoes/00000048.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000048.jpg
#   inflating: fashion_dataset/black_shoes/00000060.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000060.jpg
#   inflating: fashion_dataset/black_shoes/00000128.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000128.jpg
#   inflating: fashion_dataset/black_shoes/00000100.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000100.jpg
#   inflating: fashion_dataset/black_shoes/00000114.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000114.jpg
#   inflating: fashion_dataset/black_shoes/00000374.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000374.jpeg
#   inflating: fashion_dataset/black_shoes/00000302.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000302.jpg
#   inflating: fashion_dataset/black_shoes/00000316.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000316.jpg
#   inflating: fashion_dataset/black_shoes/00000300.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000300.jpg
#   inflating: fashion_dataset/black_shoes/00000314.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000314.jpg
#   inflating: fashion_dataset/black_shoes/00000328.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000328.jpg
#   inflating: fashion_dataset/black_shoes/00000116.png
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000116.png
#   inflating: fashion_dataset/black_shoes/00000303.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000303.jpeg
#   inflating: fashion_dataset/black_shoes/00000076.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000076.jpg
#   inflating: fashion_dataset/black_shoes/00000062.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000062.jpg
#   inflating: fashion_dataset/black_shoes/00000089.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000089.jpg
#   inflating: fashion_dataset/black_shoes/00000274.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000274.jpg
#   inflating: fashion_dataset/black_shoes/00000260.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000260.jpg
#   inflating: fashion_dataset/black_shoes/00000047.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000047.jpeg
#   inflating: fashion_dataset/black_shoes/00000249.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000249.jpg
#   inflating: fashion_dataset/black_shoes/00000275.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000275.jpg
#   inflating: fashion_dataset/black_shoes/00000088.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000088.jpg
#   inflating: fashion_dataset/black_shoes/00000155.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000155.jpeg
#   inflating: fashion_dataset/black_shoes/00000063.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000063.jpg
#   inflating: fashion_dataset/black_shoes/00000117.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000117.jpg
#   inflating: fashion_dataset/black_shoes/00000103.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000103.jpg
#   inflating: fashion_dataset/black_shoes/00000329.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000329.JPG
#   inflating: fashion_dataset/black_shoes/00000315.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000315.jpg
#   inflating: fashion_dataset/black_shoes/00000301.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000301.jpg
#   inflating: fashion_dataset/black_shoes/00000318.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000318.jpg
#   inflating: fashion_dataset/black_shoes/00000324.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000324.jpg
#   inflating: fashion_dataset/black_shoes/00000330.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000330.jpg
#   inflating: fashion_dataset/black_shoes/00000126.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000126.jpg
#   inflating: fashion_dataset/black_shoes/00000132.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000132.jpg
#   inflating: fashion_dataset/black_shoes/00000052.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000052.jpg
#   inflating: fashion_dataset/black_shoes/00000091.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000091.jpg
#   inflating: fashion_dataset/black_shoes/00000278.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000278.jpg
#   inflating: fashion_dataset/black_shoes/00000250.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000250.jpg
#   inflating: fashion_dataset/black_shoes/00000244.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000244.JPG
#   inflating: fashion_dataset/black_shoes/00000287.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000287.jpg
#   inflating: fashion_dataset/black_shoes/00000286.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000286.jpg
#   inflating: fashion_dataset/black_shoes/00000292.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000292.jpg
#   inflating: fashion_dataset/black_shoes/00000245.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000245.jpg
#   inflating: fashion_dataset/black_shoes/00000251.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000251.jpg
#   inflating: fashion_dataset/black_shoes/00000279.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000279.jpg
#   inflating: fashion_dataset/black_shoes/00000084.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000084.JPG
#   inflating: fashion_dataset/black_shoes/00000090.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000090.jpg
#   inflating: fashion_dataset/black_shoes/00000053.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000053.jpg
#   inflating: fashion_dataset/black_shoes/00000325.png
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000325.png
#   inflating: fashion_dataset/black_shoes/00000133.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000133.jpg
#   inflating: fashion_dataset/black_shoes/00000127.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000127.jpg
#   inflating: fashion_dataset/black_shoes/00000331.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000331.JPG
#   inflating: fashion_dataset/black_shoes/00000319.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000319.jpg
#   inflating: fashion_dataset/black_shoes/00000333.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000333.jpg
#   inflating: fashion_dataset/black_shoes/00000119.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000119.jpg
#   inflating: fashion_dataset/black_shoes/00000131.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000131.jpg
#   inflating: fashion_dataset/black_shoes/00000125.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000125.jpg
#   inflating: fashion_dataset/black_shoes/00000079.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000079.jpg
#   inflating: fashion_dataset/black_shoes/00000045.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000045.jpg
#   inflating: fashion_dataset/black_shoes/00000051.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000051.jpg
#   inflating: fashion_dataset/black_shoes/00000086.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000086.jpg
#   inflating: fashion_dataset/black_shoes/00000092.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000092.jpg
#   inflating: fashion_dataset/black_shoes/00000247.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000247.jpg
#   inflating: fashion_dataset/black_shoes/00000253.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000253.JPG
#   inflating: fashion_dataset/black_shoes/00000284.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000284.JPG
#   inflating: fashion_dataset/black_shoes/00000290.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000290.jpg
#   inflating: fashion_dataset/black_shoes/00000291.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000291.jpg
#   inflating: fashion_dataset/black_shoes/00000285.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000285.jpg
#   inflating: fashion_dataset/black_shoes/00000252.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000252.jpg
#   inflating: fashion_dataset/black_shoes/00000246.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000246.jpg
#   inflating: fashion_dataset/black_shoes/00000093.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000093.jpg
#   inflating: fashion_dataset/black_shoes/00000087.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000087.jpg
#   inflating: fashion_dataset/black_shoes/00000044.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000044.jpg
#   inflating: fashion_dataset/black_shoes/00000078.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000078.jpg
#   inflating: fashion_dataset/black_shoes/00000124.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000124.jpg
#   inflating: fashion_dataset/black_shoes/00000130.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000130.jpg
#   inflating: fashion_dataset/black_shoes/00000118.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000118.jpg
#   inflating: fashion_dataset/black_shoes/00000199.gif
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000199.gif
#   inflating: fashion_dataset/black_shoes/00000332.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000332.jpg
#   inflating: fashion_dataset/black_shoes/00000336.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000336.jpg
#   inflating: fashion_dataset/black_shoes/00000322.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000322.jpg
#   inflating: fashion_dataset/black_shoes/00000134.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000134.jpg
#   inflating: fashion_dataset/black_shoes/00000120.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000120.jpg
#   inflating: fashion_dataset/black_shoes/00000108.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000108.jpg
#   inflating: fashion_dataset/black_shoes/00000040.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000040.jpg
#   inflating: fashion_dataset/black_shoes/00000054.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000054.jpg
#   inflating: fashion_dataset/black_shoes/00000068.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000068.jpg
#   inflating: fashion_dataset/black_shoes/00000097.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000097.jpg
#   inflating: fashion_dataset/black_shoes/00000242.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000242.jpg
#   inflating: fashion_dataset/black_shoes/00000281.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000281.jpg
#   inflating: fashion_dataset/black_shoes/00000295.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000295.JPG
#   inflating: fashion_dataset/black_shoes/00000294.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000294.jpg
#   inflating: fashion_dataset/black_shoes/00000280.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000280.jpg
#   inflating: fashion_dataset/black_shoes/00000032.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000032.jpeg
#   inflating: fashion_dataset/black_shoes/00000257.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000257.jpg
#   inflating: fashion_dataset/black_shoes/00000243.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000243.jpg
#   inflating: fashion_dataset/black_shoes/00000096.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000096.jpg
#   inflating: fashion_dataset/black_shoes/00000082.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000082.jpg
#   inflating: fashion_dataset/black_shoes/00000069.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000069.jpg
#   inflating: fashion_dataset/black_shoes/00000055.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000055.jpg
#   inflating: fashion_dataset/black_shoes/00000041.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000041.jpg
#   inflating: fashion_dataset/black_shoes/00000337.png
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000337.png
#   inflating: fashion_dataset/black_shoes/00000109.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000109.jpg
#   inflating: fashion_dataset/black_shoes/00000121.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000121.jpg
#   inflating: fashion_dataset/black_shoes/00000135.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000135.jpg
#   inflating: fashion_dataset/black_shoes/00000323.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000323.jpg
#   inflating: fashion_dataset/black_shoes/00000248.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000248.jpeg
#   inflating: fashion_dataset/black_shoes/00000321.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000321.jpg
#   inflating: fashion_dataset/black_shoes/00000335.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000335.jpg
#   inflating: fashion_dataset/black_shoes/00000309.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000309.jpg
#   inflating: fashion_dataset/black_shoes/00000123.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000123.jpg
#   inflating: fashion_dataset/black_shoes/00000137.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000137.jpg
#   inflating: fashion_dataset/black_shoes/00000057.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000057.jpg
#   inflating: fashion_dataset/black_shoes/00000043.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000043.jpg
#   inflating: fashion_dataset/black_shoes/00000094.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000094.jpg
#   inflating: fashion_dataset/black_shoes/00000080.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000080.jpg
#   inflating: fashion_dataset/black_shoes/00000255.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000255.jpg
#   inflating: fashion_dataset/black_shoes/00000269.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000269.jpg
#   inflating: fashion_dataset/black_shoes/00000296.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000296.jpg
#   inflating: fashion_dataset/black_shoes/00000282.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000282.jpg
#   inflating: fashion_dataset/black_shoes/00000268.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000268.jpg
#   inflating: fashion_dataset/black_shoes/00000240.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000240.jpg
#   inflating: fashion_dataset/black_shoes/00000254.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000254.jpg
#   inflating: fashion_dataset/black_shoes/00000081.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000081.jpg
#   inflating: fashion_dataset/black_shoes/00000095.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000095.jpg
#   inflating: fashion_dataset/black_shoes/00000042.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000042.jpg
#   inflating: fashion_dataset/black_shoes/00000297.png
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000297.png
#   inflating: fashion_dataset/black_shoes/00000056.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000056.jpg
#   inflating: fashion_dataset/black_shoes/00000136.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000136.jpg
#   inflating: fashion_dataset/black_shoes/00000122.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000122.jpg
#   inflating: fashion_dataset/black_shoes/00000308.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000308.jpg
#   inflating: fashion_dataset/black_shoes/00000334.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000334.jpg
#   inflating: fashion_dataset/black_shoes/00000320.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000320.jpg
#   inflating: fashion_dataset/black_shoes/00000347.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000347.jpg
#   inflating: fashion_dataset/black_shoes/00000353.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000353.jpg
#   inflating: fashion_dataset/black_shoes/00000179.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000179.jpg
#   inflating: fashion_dataset/black_shoes/00000145.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000145.JPG
#   inflating: fashion_dataset/black_shoes/00000151.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000151.jpg
#   inflating: fashion_dataset/black_shoes/00000186.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000186.jpg
#   inflating: fashion_dataset/black_shoes/00000074.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000074.jpeg
#   inflating: fashion_dataset/black_shoes/00000192.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000192.jpg
#   inflating: fashion_dataset/black_shoes/00000019.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000019.jpg
#   inflating: fashion_dataset/black_shoes/00000031.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000031.jpg
#   inflating: fashion_dataset/black_shoes/00000025.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000025.jpg
#   inflating: fashion_dataset/black_shoes/00000227.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000227.jpg
#   inflating: fashion_dataset/black_shoes/00000226.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000226.JPG
#   inflating: fashion_dataset/black_shoes/00000232.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000232.jpg
#   inflating: fashion_dataset/black_shoes/00000024.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000024.jpg
#   inflating: fashion_dataset/black_shoes/00000030.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000030.jpg
#   inflating: fashion_dataset/black_shoes/00000018.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000018.jpg
#   inflating: fashion_dataset/black_shoes/00000187.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000187.jpg
#   inflating: fashion_dataset/black_shoes/00000150.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000150.jpg
#   inflating: fashion_dataset/black_shoes/00000144.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000144.jpg
#   inflating: fashion_dataset/black_shoes/00000352.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000352.jpg
#   inflating: fashion_dataset/black_shoes/00000058.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000058.jpeg
#   inflating: fashion_dataset/black_shoes/00000346.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000346.jpg
#   inflating: fashion_dataset/black_shoes/00000378.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000378.jpg
#   inflating: fashion_dataset/black_shoes/00000350.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000350.jpg
#   inflating: fashion_dataset/black_shoes/00000344.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000344.jpg
#   inflating: fashion_dataset/black_shoes/00000152.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000152.jpg
#   inflating: fashion_dataset/black_shoes/00000146.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000146.jpg
#   inflating: fashion_dataset/black_shoes/00000191.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000191.jpg
#   inflating: fashion_dataset/black_shoes/00000185.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000185.jpg
#   inflating: fashion_dataset/black_shoes/00000026.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000026.jpg
#   inflating: fashion_dataset/black_shoes/00000218.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000218.jpg
#   inflating: fashion_dataset/black_shoes/00000224.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000224.jpg
#   inflating: fashion_dataset/black_shoes/00000230.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000230.JPG
#   inflating: fashion_dataset/black_shoes/00000039.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000039.jpeg
#   inflating: fashion_dataset/black_shoes/00000193.jpeg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000193.jpeg
#   inflating: fashion_dataset/black_shoes/00000231.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000231.jpg
#   inflating: fashion_dataset/black_shoes/00000225.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000225.jpg
#   inflating: fashion_dataset/black_shoes/00000219.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000219.jpg
#   inflating: fashion_dataset/black_shoes/00000033.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000033.jpg
#   inflating: fashion_dataset/black_shoes/00000190.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000190.jpg
#   inflating: fashion_dataset/black_shoes/00000147.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000147.jpg
#   inflating: fashion_dataset/black_shoes/00000153.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000153.jpg
#   inflating: fashion_dataset/black_shoes/00000345.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000345.jpg
#   inflating: fashion_dataset/black_shoes/00000351.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000351.jpg
#   inflating: fashion_dataset/black_shoes/00000355.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000355.jpg
#   inflating: fashion_dataset/black_shoes/00000341.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000341.jpg
#   inflating: fashion_dataset/black_shoes/00000369.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000369.jpg
#   inflating: fashion_dataset/black_shoes/00000157.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000157.jpg
#   inflating: fashion_dataset/black_shoes/00000143.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000143.jpg
#   inflating: fashion_dataset/black_shoes/00000194.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000194.jpg
#   inflating: fashion_dataset/black_shoes/00000180.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000180.jpg
#   inflating: fashion_dataset/black_shoes/00000023.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000023.jpg
#   inflating: fashion_dataset/black_shoes/00000037.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000037.jpg
#   inflating: fashion_dataset/black_shoes/00000221.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000221.jpg
#   inflating: fashion_dataset/black_shoes/00000235.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000235.jpg
#   inflating: fashion_dataset/black_shoes/00000209.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000209.jpg
#   inflating: fashion_dataset/black_shoes/00000208.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000208.jpg
#   inflating: fashion_dataset/black_shoes/00000234.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000234.jpg
#   inflating: fashion_dataset/black_shoes/00000220.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000220.jpg
#   inflating: fashion_dataset/black_shoes/00000036.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000036.jpg
#   inflating: fashion_dataset/black_shoes/00000022.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000022.jpg
#   inflating: fashion_dataset/black_shoes/00000181.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000181.jpg
#   inflating: fashion_dataset/black_shoes/00000195.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000195.jpg
#   inflating: fashion_dataset/black_shoes/00000142.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000142.jpg
#   inflating: fashion_dataset/black_shoes/00000156.JPG
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000156.JPG
#   inflating: fashion_dataset/black_shoes/00000383.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000383.jpg
#   inflating: fashion_dataset/black_shoes/00000340.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000340.jpg
#   inflating: fashion_dataset/black_shoes/00000354.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000354.jpg
#   inflating: fashion_dataset/black_shoes/00000342.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000342.jpg
#   inflating: fashion_dataset/black_shoes/00000356.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000356.jpg
#   inflating: fashion_dataset/black_shoes/00000381.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000381.jpg
#   inflating: fashion_dataset/black_shoes/00000140.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000140.jpg
#   inflating: fashion_dataset/black_shoes/00000154.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000154.jpg
#   inflating: fashion_dataset/black_shoes/00000168.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000168.jpg
#   inflating: fashion_dataset/black_shoes/00000183.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000183.jpg
#   inflating: fashion_dataset/black_shoes/00000034.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000034.jpg
#   inflating: fashion_dataset/black_shoes/00000020.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000020.jpg
#   inflating: fashion_dataset/black_shoes/00000008.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000008.jpg
#   inflating: fashion_dataset/black_shoes/00000236.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000236.jpg
#   inflating: fashion_dataset/black_shoes/00000222.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000222.jpg
#   inflating: fashion_dataset/black_shoes/00000223.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000223.jpg
#   inflating: fashion_dataset/black_shoes/00000237.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000237.jpg
#   inflating: fashion_dataset/black_shoes/00000009.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000009.jpg
#   inflating: fashion_dataset/black_shoes/00000021.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000021.jpg
#   inflating: fashion_dataset/black_shoes/00000035.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000035.jpg
#   inflating: fashion_dataset/black_shoes/00000196.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000196.jpg
#   inflating: fashion_dataset/black_shoes/00000182.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000182.jpg
#   inflating: fashion_dataset/black_shoes/00000169.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000169.jpg
#   inflating: fashion_dataset/black_shoes/00000141.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000141.jpg
#   inflating: fashion_dataset/black_shoes/00000380.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000380.jpg
#   inflating: fashion_dataset/black_shoes/00000357.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000357.jpg
#   inflating: fashion_dataset/black_shoes/00000343.jpg
#   inflating: __MACOSX/fashion_dataset/black_shoes/._00000343.jpg
#   inflating: __MACOSX/fashion_dataset/._black_shoes
#    creating: fashion_dataset/red_dress/
#   inflating: fashion_dataset/red_dress/00000366.jpg
#    creating: __MACOSX/fashion_dataset/red_dress/
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000366.jpg
#   inflating: fashion_dataset/red_dress/00000372.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000372.jpg
#   inflating: fashion_dataset/red_dress/00000158.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000158.jpg
#   inflating: fashion_dataset/red_dress/00000164.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000164.jpg
#   inflating: fashion_dataset/red_dress/00000170.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000170.jpg
#   inflating: fashion_dataset/red_dress/00000038.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000038.jpg
#   inflating: fashion_dataset/red_dress/00000010.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000010.jpg
#   inflating: fashion_dataset/red_dress/00000004.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000004.jpg
#   inflating: fashion_dataset/red_dress/00000212.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000212.jpg
#   inflating: fashion_dataset/red_dress/00000206.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000206.jpg
#   inflating: fashion_dataset/red_dress/00000207.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000207.jpg
#   inflating: fashion_dataset/red_dress/00000213.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000213.jpg
#   inflating: fashion_dataset/red_dress/00000125.jpeg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000125.jpeg
#   inflating: fashion_dataset/red_dress/00000005.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000005.jpg
#   inflating: fashion_dataset/red_dress/00000011.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000011.jpg
#   inflating: fashion_dataset/red_dress/00000039.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000039.jpg
#   inflating: fashion_dataset/red_dress/00000165.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000165.jpg
#   inflating: fashion_dataset/red_dress/00000159.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000159.jpg
#   inflating: fashion_dataset/red_dress/00000373.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000373.jpg
#   inflating: fashion_dataset/red_dress/00000367.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000367.jpg
#   inflating: fashion_dataset/red_dress/00000359.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000359.jpg
#   inflating: fashion_dataset/red_dress/00000371.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000371.jpg
#   inflating: fashion_dataset/red_dress/00000365.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000365.jpg
#   inflating: fashion_dataset/red_dress/00000282.jpeg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000282.jpeg
#   inflating: fashion_dataset/red_dress/00000173.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000173.jpg
#   inflating: fashion_dataset/red_dress/00000167.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000167.jpg
#   inflating: fashion_dataset/red_dress/00000144.jpeg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000144.jpeg
#   inflating: fashion_dataset/red_dress/00000198.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000198.jpg
#   inflating: fashion_dataset/red_dress/00000007.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000007.jpg
#   inflating: fashion_dataset/red_dress/00000013.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000013.jpg
#   inflating: fashion_dataset/red_dress/00000239.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000239.jpg
#   inflating: fashion_dataset/red_dress/00000205.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000205.jpg
#   inflating: fashion_dataset/red_dress/00000210.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000210.jpg
#   inflating: fashion_dataset/red_dress/00000238.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000238.jpg
#   inflating: fashion_dataset/red_dress/00000200.jpeg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000200.jpeg
#   inflating: fashion_dataset/red_dress/00000012.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000012.jpg
#   inflating: fashion_dataset/red_dress/00000006.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000006.jpg
#   inflating: fashion_dataset/red_dress/00000199.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000199.jpg
#   inflating: fashion_dataset/red_dress/00000166.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000166.jpg
#   inflating: fashion_dataset/red_dress/00000304.jpeg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000304.jpeg
#   inflating: fashion_dataset/red_dress/00000364.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000364.jpg
#   inflating: fashion_dataset/red_dress/00000370.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000370.jpg
#   inflating: fashion_dataset/red_dress/00000358.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000358.jpg
#   inflating: fashion_dataset/red_dress/00000374.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000374.jpg
#   inflating: fashion_dataset/red_dress/00000360.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000360.jpg
#   inflating: fashion_dataset/red_dress/00000240.jpeg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000240.jpeg
#   inflating: fashion_dataset/red_dress/00000176.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000176.jpg
#   inflating: fashion_dataset/red_dress/00000162.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000162.jpg
#   inflating: fashion_dataset/red_dress/00000189.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000189.jpg
#   inflating: fashion_dataset/red_dress/00000002.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000002.jpg
#   inflating: fashion_dataset/red_dress/00000016.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000016.jpg
#   inflating: fashion_dataset/red_dress/00000214.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000214.jpg
#   inflating: fashion_dataset/red_dress/00000228.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000228.jpg
#   inflating: fashion_dataset/red_dress/00000215.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000215.jpg
#   inflating: fashion_dataset/red_dress/00000201.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000201.jpg
#   inflating: fashion_dataset/red_dress/00000017.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000017.jpg
#   inflating: fashion_dataset/red_dress/00000257.gif
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000257.gif
#   inflating: fashion_dataset/red_dress/00000003.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000003.jpg
#   inflating: fashion_dataset/red_dress/00000145.jpeg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000145.jpeg
#   inflating: fashion_dataset/red_dress/00000188.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000188.jpg
#   inflating: fashion_dataset/red_dress/00000163.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000163.jpg
#   inflating: fashion_dataset/red_dress/00000177.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000177.jpg
#   inflating: fashion_dataset/red_dress/00000349.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000349.jpg
#   inflating: fashion_dataset/red_dress/00000361.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000361.jpg
#   inflating: fashion_dataset/red_dress/00000375.JPG
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000375.JPG
#   inflating: fashion_dataset/red_dress/00000363.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000363.jpg
#   inflating: fashion_dataset/red_dress/00000377.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000377.jpg
#   inflating: fashion_dataset/red_dress/00000388.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000388.jpg
#   inflating: fashion_dataset/red_dress/00000161.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000161.jpg
#   inflating: fashion_dataset/red_dress/00000175.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000175.jpg
#   inflating: fashion_dataset/red_dress/00000149.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000149.jpg
#   inflating: fashion_dataset/red_dress/00000015.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000015.jpg
#   inflating: fashion_dataset/red_dress/00000001.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000001.jpg
#   inflating: fashion_dataset/red_dress/00000348.jpeg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000348.jpeg
#   inflating: fashion_dataset/red_dress/00000217.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000217.jpg
#   inflating: fashion_dataset/red_dress/00000029.png
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000029.png
#   inflating: fashion_dataset/red_dress/00000202.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000202.jpg
#   inflating: fashion_dataset/red_dress/00000216.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000216.jpg
#   inflating: fashion_dataset/red_dress/00000028.jpg
#   inflating: __MACOSX/fashion_dataset/red_dress/._00000028.jpg
#   inflating: fashion_dataset/red_dress/00000000.jpg
# ...
#   inflating: fashion_dataset/blue_shirt/00000297.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000297.jpg
#   inflating: fashion_dataset/blue_shirt/00000268.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000268.jpg
#   inflating: fashion_dataset/blue_shirt/00000254.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000254.jpg
#   inflating: fashion_dataset/blue_shirt/00000081.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000081.jpg
#   inflating: fashion_dataset/blue_shirt/00000095.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000095.jpg
#   inflating: fashion_dataset/blue_shirt/00000240.png
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000240.png
#   inflating: fashion_dataset/blue_shirt/00000042.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000042.jpg
#   inflating: fashion_dataset/blue_shirt/00000356.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000356.jpeg
#   inflating: fashion_dataset/blue_shirt/00000136.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000136.jpg
#   inflating: fashion_dataset/blue_shirt/00000122.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000122.jpg
#   inflating: fashion_dataset/blue_shirt/00000308.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000308.jpg
#   inflating: fashion_dataset/blue_shirt/00000320.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000320.jpg
#   inflating: fashion_dataset/blue_shirt/00000028.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000028.jpeg
#   inflating: fashion_dataset/blue_shirt/00000347.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000347.jpg
#   inflating: fashion_dataset/blue_shirt/00000353.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000353.jpg
#   inflating: fashion_dataset/blue_shirt/00000384.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000384.jpg
#   inflating: fashion_dataset/blue_shirt/00000189.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000189.jpeg
#   inflating: fashion_dataset/blue_shirt/00000179.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000179.jpg
#   inflating: fashion_dataset/blue_shirt/00000218.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000218.jpeg
#   inflating: fashion_dataset/blue_shirt/00000151.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000151.jpg
#   inflating: fashion_dataset/blue_shirt/00000131.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000131.jpeg
#   inflating: fashion_dataset/blue_shirt/00000186.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000186.jpg
#   inflating: fashion_dataset/blue_shirt/00000192.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000192.jpg
#   inflating: fashion_dataset/blue_shirt/00000019.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000019.jpg
#   inflating: fashion_dataset/blue_shirt/00000031.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000031.jpg
#   inflating: fashion_dataset/blue_shirt/00000025.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000025.jpg
#   inflating: fashion_dataset/blue_shirt/00000233.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000233.jpg
#   inflating: fashion_dataset/blue_shirt/00000227.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000227.jpg
#   inflating: fashion_dataset/blue_shirt/00000170.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000170.jpeg
#   inflating: fashion_dataset/blue_shirt/00000226.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000226.jpg
#   inflating: fashion_dataset/blue_shirt/00000232.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000232.jpg
#   inflating: fashion_dataset/blue_shirt/00000275.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000275.jpeg
#   inflating: fashion_dataset/blue_shirt/00000024.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000024.jpg
#   inflating: fashion_dataset/blue_shirt/00000030.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000030.jpg
#   inflating: fashion_dataset/blue_shirt/00000018.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000018.jpg
#   inflating: fashion_dataset/blue_shirt/00000263.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000263.jpeg
#   inflating: fashion_dataset/blue_shirt/00000187.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000187.jpg
#   inflating: fashion_dataset/blue_shirt/00000144.JPG
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000144.JPG
#   inflating: fashion_dataset/blue_shirt/00000178.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000178.jpg
#   inflating: fashion_dataset/blue_shirt/00000352.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000352.jpg
#   inflating: fashion_dataset/blue_shirt/00000346.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000346.jpg
#   inflating: fashion_dataset/blue_shirt/00000378.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000378.jpg
#   inflating: fashion_dataset/blue_shirt/00000350.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000350.jpg
#   inflating: fashion_dataset/blue_shirt/00000344.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000344.jpg
#   inflating: fashion_dataset/blue_shirt/00000152.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000152.jpg
#   inflating: fashion_dataset/blue_shirt/00000146.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000146.jpg
#   inflating: fashion_dataset/blue_shirt/00000191.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000191.jpg
#   inflating: fashion_dataset/blue_shirt/00000185.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000185.jpg
#   inflating: fashion_dataset/blue_shirt/00000026.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000026.jpg
#   inflating: fashion_dataset/blue_shirt/00000224.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000224.jpg
#   inflating: fashion_dataset/blue_shirt/00000230.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000230.jpg
#   inflating: fashion_dataset/blue_shirt/00000193.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000193.jpeg
#   inflating: fashion_dataset/blue_shirt/00000032.png
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000032.png
#   inflating: fashion_dataset/blue_shirt/00000231.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000231.jpg
#   inflating: fashion_dataset/blue_shirt/00000219.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000219.jpg
#   inflating: fashion_dataset/blue_shirt/00000150.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000150.jpeg
#   inflating: fashion_dataset/blue_shirt/00000033.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000033.jpg
#   inflating: fashion_dataset/blue_shirt/00000027.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000027.jpg
#   inflating: fashion_dataset/blue_shirt/00000184.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000184.jpg
#   inflating: fashion_dataset/blue_shirt/00000190.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000190.jpg
#   inflating: fashion_dataset/blue_shirt/00000147.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000147.jpg
#   inflating: fashion_dataset/blue_shirt/00000153.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000153.jpg
#   inflating: fashion_dataset/blue_shirt/00000345.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000345.jpg
#   inflating: fashion_dataset/blue_shirt/00000351.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000351.jpg
#   inflating: fashion_dataset/blue_shirt/00000379.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000379.jpg
#   inflating: fashion_dataset/blue_shirt/00000341.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000341.jpg
#   inflating: fashion_dataset/blue_shirt/00000369.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000369.jpg
#   inflating: fashion_dataset/blue_shirt/00000382.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000382.jpg
#   inflating: fashion_dataset/blue_shirt/00000157.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000157.jpg
#   inflating: fashion_dataset/blue_shirt/00000143.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000143.jpg
#   inflating: fashion_dataset/blue_shirt/00000194.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000194.jpg
#   inflating: fashion_dataset/blue_shirt/00000180.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000180.jpg
#   inflating: fashion_dataset/blue_shirt/00000002.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000002.jpeg
#   inflating: fashion_dataset/blue_shirt/00000023.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000023.jpg
#   inflating: fashion_dataset/blue_shirt/00000037.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000037.jpg
#   inflating: fashion_dataset/blue_shirt/00000221.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000221.jpg
#   inflating: fashion_dataset/blue_shirt/00000385.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000385.jpeg
#   inflating: fashion_dataset/blue_shirt/00000235.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000235.jpg
#   inflating: fashion_dataset/blue_shirt/00000209.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000209.jpg
#   inflating: fashion_dataset/blue_shirt/00000022.png
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000022.png
#   inflating: fashion_dataset/blue_shirt/00000234.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000234.jpg
#   inflating: fashion_dataset/blue_shirt/00000220.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000220.jpg
#   inflating: fashion_dataset/blue_shirt/00000036.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000036.jpg
#   inflating: fashion_dataset/blue_shirt/00000195.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000195.jpg
#   inflating: fashion_dataset/blue_shirt/00000142.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000142.jpg
#   inflating: fashion_dataset/blue_shirt/00000156.JPG
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000156.JPG
#   inflating: fashion_dataset/blue_shirt/00000383.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000383.jpg
#   inflating: fashion_dataset/blue_shirt/00000368.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000368.jpg
#   inflating: fashion_dataset/blue_shirt/00000340.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000340.jpg
#   inflating: fashion_dataset/blue_shirt/00000354.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000354.jpg
#   inflating: fashion_dataset/blue_shirt/00000181.png
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000181.png
#   inflating: fashion_dataset/blue_shirt/00000342.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000342.jpg
#   inflating: fashion_dataset/blue_shirt/00000059.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000059.jpeg
#   inflating: fashion_dataset/blue_shirt/00000381.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000381.jpg
#   inflating: fashion_dataset/blue_shirt/00000370.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000370.jpeg
#   inflating: fashion_dataset/blue_shirt/00000140.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000140.jpg
#   inflating: fashion_dataset/blue_shirt/00000154.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000154.jpg
#   inflating: fashion_dataset/blue_shirt/00000168.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000168.jpg
#   inflating: fashion_dataset/blue_shirt/00000183.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000183.jpg
#   inflating: fashion_dataset/blue_shirt/00000262.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000262.jpeg
#   inflating: fashion_dataset/blue_shirt/00000197.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000197.jpg
#   inflating: fashion_dataset/blue_shirt/00000327.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000327.jpeg
#   inflating: fashion_dataset/blue_shirt/00000008.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000008.jpg
#   inflating: fashion_dataset/blue_shirt/00000274.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000274.jpeg
#   inflating: fashion_dataset/blue_shirt/00000236.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000236.jpg
#   inflating: fashion_dataset/blue_shirt/00000222.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000222.jpg
#   inflating: fashion_dataset/blue_shirt/00000020.png
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000020.png
#   inflating: fashion_dataset/blue_shirt/00000034.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000034.jpeg
#   inflating: fashion_dataset/blue_shirt/00000223.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000223.jpg
#   inflating: fashion_dataset/blue_shirt/00000237.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000237.jpg
#   inflating: fashion_dataset/blue_shirt/00000009.JPG
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000009.JPG
#   inflating: fashion_dataset/blue_shirt/00000021.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000021.jpg
#   inflating: fashion_dataset/blue_shirt/00000035.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000035.jpg
#   inflating: fashion_dataset/blue_shirt/00000196.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000196.jpg
#   inflating: fashion_dataset/blue_shirt/00000182.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000182.jpg
#   inflating: fashion_dataset/blue_shirt/00000155.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000155.jpg
#   inflating: fashion_dataset/blue_shirt/00000141.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000141.jpg
#   inflating: fashion_dataset/blue_shirt/00000169.png
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000169.png
#   inflating: fashion_dataset/blue_shirt/00000380.jpg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000380.jpg
#   inflating: fashion_dataset/blue_shirt/00000188.jpeg
#   inflating: __MACOSX/fashion_dataset/blue_shirt/._00000188.jpeg
#   inflating: __MACOSX/fashion_dataset/._blue_shirt
#   inflating: __MACOSX/._fashion_dataset
#    creating: fashion_examples/
#    creating: fashion_examples/images/
#   inflating: fashion_examples/images/blue_shirt.jpg
#    creating: __MACOSX/fashion_examples/
#    creating: __MACOSX/fashion_examples/images/
#   inflating: __MACOSX/fashion_examples/images/._blue_shirt.jpg
#   inflating: fashion_examples/images/red_shirt.jpg
#   inflating: __MACOSX/fashion_examples/images/._red_shirt.jpg
#   inflating: fashion_examples/images/black_dress.jpg
#   inflating: __MACOSX/fashion_examples/images/._black_dress.jpg
#   inflating: fashion_examples/images/blue_jeans.jpg
#   inflating: __MACOSX/fashion_examples/images/._blue_jeans.jpg
#   inflating: fashion_examples/images/red_dress.jpg
#   inflating: __MACOSX/fashion_examples/images/._red_dress.jpg
#   inflating: fashion_examples/images/blue_dress.jpg
#   inflating: __MACOSX/fashion_examples/images/._blue_dress.jpg
#   inflating: fashion_examples/images/black_jeans.jpg
#   inflating: __MACOSX/fashion_examples/images/._black_jeans.jpg
#   inflating: fashion_examples/images/blue_shoes.jpg
#   inflating: __MACOSX/fashion_examples/images/._blue_shoes.jpg
#   inflating: fashion_examples/images/red_shoes.jpg
#   inflating: __MACOSX/fashion_examples/images/._red_shoes.jpg
#   inflating: __MACOSX/fashion_examples/._images
#   inflating: __MACOSX/._fashion_examples

# %% [markdown]
# #### Data Preprocessing
#
# As you already know, data should be formatted into appropriately pre-processed floating-point tensors before being fed into your networks. Currently, your data sits on a drive as JPEG files, so the steps for getting it into a network are roughly:
# * Read the picture files.
# * Decode the JPEG content to RBG grids of pixels.
# * Convert these into floating-point tensors.
# * Rescale the pixel values (between 0 and 255) to the [0, 1] interval (neural networks prefer to deal with small input values).
#
# It may seem a bit daunting, but thankfully Keras has utilities to take care of these steps automatically. Keras has a module with image processing helper tools, located at `keras.preprocessing.image`. In particular, it contains the class `ImageDataGenerator` which allows you to quickly set up Python generators that can automatically turn image files on disk into batches of pre-processed tensors. Read the [doc](https://keras.io/preprocessing/image/) for more information.
#
# **Tips:** If you want to use data augmentation at a later time, come back here and create a new `ImageDataGenerator` with the appropriate parameters.

# %%
# target image size
n_pix = 40

# All images will be rescaled by 1./255
datagen = image.ImageDataGenerator(rescale=1./255, validation_split=0.2)

# train set
train_generator = datagen.flow_from_directory("fashion_dataset", subset='training', target_size=(n_pix,n_pix), batch_size=32)

# validation set
valid_generator = datagen.flow_from_directory("fashion_dataset", subset='validation', target_size=(n_pix,n_pix), batch_size=32)
# Out:
# Found 2020 images belonging to 7 classes.
# Found 501 images belonging to 7 classes.

# %% [markdown]
# Let's take a look at the output of these generators. They yield batches of 40x40 RGB images and their corresponding labels, with 32 samples in each batch. Note that a generator yields these batches indefinitely: it just loops endlessly over the images present in the target folder.

# %%
for data_batch, labels_batch in train_generator:
    
    print('data batch shape:', data_batch.shape)
    print('data label shape:', labels_batch.shape)
    
    plt.imshow(data_batch[0])
    plt.show()
    
    break
# Out:
# data batch shape: (32, 40, 40, 3)
# data label shape: (32, 7)

# %% [markdown]
# The labels are one-hot encoded, as shown in the cell below.

# %%
for key, value in train_generator.class_indices.items():
    print(utils.to_categorical(value, num_classes=7), "=", value, "-->", key)
# Out:
# [1. 0. 0. 0. 0. 0. 0.] = 0 --> black_jeans
# [0. 1. 0. 0. 0. 0. 0.] = 1 --> black_shoes
# [0. 0. 1. 0. 0. 0. 0.] = 2 --> blue_dress
# [0. 0. 0. 1. 0. 0. 0.] = 3 --> blue_jeans
# [0. 0. 0. 0. 1. 0. 0.] = 4 --> blue_shirt
# [0. 0. 0. 0. 0. 1. 0.] = 5 --> red_dress
# [0. 0. 0. 0. 0. 0. 1.] = 6 --> red_shirt

# %% [markdown]
# ## 2. Multi-Class Classification
#
# **Exercise:** Build a ConvNet for multi-class classification. It must predict the 7 classes available in the dataset.
#
# - Define the architecture of your ConvNet.
#
# - Fit the ConvNet on the training set.
#
# - Evaluate its performance on the validation set.
#
# - Test your trained ConvNet on the images in the folder `fashion_examples`.
#
# **Tips:**
#
#  - Remember that the structure of a ConvNet starts off with a stack of alternated `Conv2D => Relu` and `MaxPooling2D` layers, which are then followed by a `Flatten` layer and several `Dense` layers.
#
#
#  - Use a **small network**, otherwise you will not be able to train it on your computer.
#
#
#  - Since you are dealing with multi-class classification, you end the network with a `softmax` activation. The number of units in this last layer is equal to the number of classes to predict. Each output will encode the probability that the network is looking at one of the classes.
#
#
#  - For multi-class classification, the loss function is `categorical_crossentropy`.

# %% [markdown]
# #### Depth-wise Separable Convolution
#
# There’s a layer you can use as a drop-in replacement for `Conv2D` that will make your model lighter (fewer trainable weight parameters) and faster (fewer floating-point operations), and cause it to perform a few percentage points better on its task. That is precisely what the depthwise separable convolution layer does, which is called
# `SeparableConv2D` in Keras.
#
# This layer performs a spatial convolution on each channel of its input, independently, before mixing output channels via a pointwise convolution (a 1x1 convolution). This is equivalent to separating the learning
# of spatial features and the learning of channel-wise features, which makes a lot of
# sense if you assume that spatial locations in the input are highly correlated, but different
# channels are fairly independent. It requires significantly fewer parameters and
# involves fewer computations, thus resulting in smaller, speedier models. And because
# it’s a more representationally efficient way to perform convolution, it tends to learn
# better representations using less data, resulting in better-performing models.
#
# These advantages become especially important when you’re training small models
# from scratch on limited data. For instance, here’s how you can build a lightweight,
# depthwise separable convnet for an image-classification task (softmax categorical classification)
# on a small dataset.

# %%
# Define the network
model = models.Sequential()
model.add(...)     # ADD CODE HERE
...                # ADD CODE HERE
model.add(...)     # ADD CODE HERE
model.compile(...) # ADD CODE HERE

# Train the network. Hint: use .fit(...)
history = ... # ADD CODE HERE

# %%
# Get the training info
loss     = history.history['loss']
val_loss = history.history['val_loss']
acc      = history.history['acc']
val_acc  = history.history['val_acc']

# Visualize the history plots
plt.figure()
plt.plot(loss, 'b', label='Training loss')
plt.plot(val_loss, 'm', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
plt.figure()
plt.plot(acc, 'b', label='Training acc')
plt.plot(val_acc, 'm', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

# %% [markdown]
# **Expected Output**:
#
# <table>
#     <tr>
#         <td>
#             Accuracy on validation set
#         </td>
#         <td>
#            around 95%
#         </td>
#     </tr>
# </table>

# %%
# Get the class names from the training set
classes = list(train_generator.class_indices.keys())

# Read the test images
test_generator = datagen.flow_from_directory("fashion_examples", class_mode=None, target_size=(n_pix,n_pix), batch_size=9)
test_images = next(test_generator)

# Test the network. Hint: use .predict() and .argmax()
preds  = None # ADD CODE HERE
labels = None # ADD CODE HERE

# Visualize the predictions
f, ax = plt.subplots(3, 3, figsize=(12,12))
for i, img in enumerate(test_images):
    ax.flat[i].imshow(img)
    ax.flat[i].axis("off")
    ax.flat[i].set_title(classes[labels[i]])
plt.show()

# %% [markdown]
# Analyze the errors made by your ConvNet on the test images.
#
# - A fraction of them is due to images classified in the wrong category. This kind of errors can be corrected by training a deeper ConvNet, and by reducing the downsampling factor on the input images (we drastically reduced the image resolution to keep the ConvNet small).
#
#
# - However, there are some images that your ConvNet can never get right, such as the black dress, the red shoes, and the blue shoes. This happens because there is no example in the training set that corresponds to black dresses, red shoes, or blue shoes. Consequently, the model does not know how to classify them. But the ConvNet is still trained to distinguish colors and clothing types. So, how can you exploit this intrinsic knowlenge of your ConvNet to correctly classify new categories of clothing? Let's find out!

# %% [markdown]
# ## 3. Multi-Class vs Multi-Label
#
# In **multi-class** classification, the model provides one separate output for each class in the training set. This is exactly what you did earlier: you built a ConvNet with as many outputs as the available classes. The mapping between the network outputs and the 7 classes in the fashion dataset is as follows:
#  - Output 1 = Black Jeans
#  - Output 2 = Black Shoes
#  - Output 3 = Blue Dress
#  - Output 4 = Blue Jeans
#  - Output 5 = Blue Shirt
#  - Output 6 = Red Dress
#  - Output 7 = Red Shirt
#
# The cell below shows the one-hot encoded labels for each class.

# %%
for key, value in train_generator.class_indices.items():
    print(utils.to_categorical(value, num_classes=7), "-->", key)

# %% [markdown]
# In **multi-label** classification, the model uses a different output convention: it provides one seperate output for each sub-class in the training set, provided that the samples belong to more than one category. For example, the fashion dataset includes two categories with several sub-classes:
#
# - **Category 1** = Clothing type
#    - *Sub-class 1.1* = Jeans
#    - *Sub-class 1.2* = Shoes
#    - *Sub-class 1.3* = Dress
#    - *Sub-class 1.4* = Shirt
#
#
# - **Category 2** = Clothing color
#    - *Sub-class 2.1* = Black
#    - *Sub-class 2.2* = Blue
#    - *Sub-class 2.3* = Red
#
# Hence, the multi-label approach implies that the mapping between the network outputs and the 7 sub-classes in the fashion dataset is as follows:
#  - Output 1 = Black
#  - Output 2 = Blue
#  - Output 3 = Dress
#  - Output 4 = Jeans
#  - Output 5 = Red
#  - Output 6 = Shirt
#  - Output 7 = Shoes
#
# The key difference here is that an item can be associated to multiple sub-classes. The cell below shows the one-hot encoded labels for the fashion dataset. Remark the difference with respect to the multi-class approach!
#
# **Note:** It is just a coincidence that the number of sub-classes is 7. This number is **not** related to multi-class classification, in which the classes were also 7.

# %%
labels = []
for key, value in train_generator.class_indices.items():
    labels.append( key.split("_") )

mlb = MultiLabelBinarizer()
multi_labels = mlb.fit_transform(labels)

for i in range(multi_labels.shape[0]):
    tags = mlb.inverse_transform(multi_labels[[i]])
    print(multi_labels[i], "-->", " ".join(*tags))

# %% [markdown]
# With a multi-label encoding, you can represent all the possible combinations of clothing types and colors.

# %%
new_labels = ["black_dress", "blue_shoes", "red_shoes"]

multi = mlb.transform([l.split("_") for l in new_labels])

for i in range(len(new_labels)):
    print(multi[i], "-->", labels[i])

# %% [markdown]
# The following class extends the Keras generator, so as to produce the multi-label one-hot encoding.

# %%
from tensorflow.keras.utils import Sequence

class MultilabelGenerator(Sequence):
    
    def __init__(self, generator):
        self.generator = generator
        self.classes = np.array([key for key, value in generator.class_indices.items()])
        labels = [tag.split("_") for tag in self.classes]
        self.mlb = MultiLabelBinarizer()
        self.mlb.fit(labels)
                
    def __next__(self):
        batch_x, batch_y = self.generator.next()
        return batch_x, self.translate_labels(batch_y)

    def __getitem__(self, i):
        batch_x, batch_y = self.generator.__getitem__(i)
        return batch_x, self.translate_labels(batch_y)

    def __len__(self):
        return len(self.generator)

    def translate_labels(self, batch_y):
        idx = batch_y.argmax(axis=1)
        batch_y = self.classes[idx]
        batch_y = [tag.split("_") for tag in batch_y]
        return self.mlb.transform(batch_y)

# %% [markdown]
# The code below prepares the generators for multi-label classification.

# %%
train_generator_multilabel = MultilabelGenerator(train_generator)
valid_generator_multilabel = MultilabelGenerator(valid_generator)

# %% [markdown]
# ## 4. Multi-Label Classification
#
# **Exercise:** Build a ConvNet for multi-label classification. It must predict the 7 sub-classes in the fashion dataset.
#
# - Define the architecture of your ConvNet.
#
# - Fit the ConvNet on the training set.
#
# - Evaluate its performance on the validation set.
#
# - Test your trained ConvNet on the images in the folder `fashion_examples`.
#
# **Tips:**
#
#  - Since you are dealing with *multi-label* classification, you end the network with a `sigmoid` activation. The number of units in this last layer is equal to the number of sub-classes to predict. Each output will encode the probability that the network is looking at one of those sub-classes.
#
#
#  - For multi-label classification, the loss function is `binary_crossentropy`.

# %%
# Define the network
model = models.Sequential()
# ADD CODE HERE

# Train the network. Hint: use .fit(...)
history = ... # ADD CODE HERE

# %%
# Get the training info
loss     = history.history['loss']
val_loss = history.history['val_loss']
acc      = history.history['acc']
val_acc  = history.history['val_acc']

# Visualize the history plots
plt.figure()
plt.plot(loss, 'b', label='Training loss')
plt.plot(val_loss, 'm', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()
plt.figure()
plt.plot(acc, 'b', label='Training acc')
plt.plot(val_acc, 'm', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

# %% [markdown]
# **Expected Output**:
#
# <table>
#     <tr>
#         <td>
#             Accuracy on validation set
#         </td>
#         <td>
#            around 98%
#         </td>
#     </tr>
# </table>

# %%
# Test the network
preds = model.predict(test_images)
preds = preds > 0.7

# Get the multi-label categories
tags = train_generator_multilabel.mlb.inverse_transform(preds)

# Visualize the predictions
f, ax = plt.subplots(3, 3, figsize=(12,12))
for i, img in enumerate(test_images):
    ax.flat[i].imshow(img)
    ax.flat[i].axis("off")
    ax.flat[i].set_title(" ".join(tags[i]))  
plt.show()

# %% [markdown]
# Analyze the errors made by your ConvNet on the test images of never-seen-before clothing (black dress, red shoes, blue shoes). Your ConvNet may only provide a partial prediction (e.g., the color), or no prediction at all. This happens because the output layer uses the SIGMOID activation, instead of SOFTMAX. Let's see how the network can be forced to always produce full predictions!

# %% [markdown]
# ## 5. Networks with arbitrary layouts
#
# So far, you have built networks with a linear sequence of layers, from input to output. It is however possible to define more complex networks. The Keras [Functional API](https://keras.io/getting-started/functional-api-guide/) is the way to go for defining arbitrary layouts, such as multi-output models, directed acyclic graphs, or models with shared layers. The functional API uses a sintax slightly different than the `Sequential` model. Let's start with some examples.
#
# ### 5.1 Single input - Single output
#
# Here is an example of ConvNet with one output layer.
#
# ```python
# # Define the input layer. Think of this as a placeholder of your input!
# X_input = layers.Input((28,28,1))
#
# # Stack the hidden layers
# X = layers.Conv2D(8, (3,3), activation='relu')(X_input)
# X = layers.BatchNormalization()(X)
# X = layers.MaxPooling2D((2,2))(X)
# X = layers.Flatten()(X)
#
# # Define the output layer
# X = layers.Dense(10, activation='softmax')(X)
#
# # Create the single-output model. This is what you'll train!
# model = models.Model(inputs = X_input, outputs = X)
# ```
#
# The next figure shows a standard model with sequential layers.
#
# ![model_single_output.png](attachment:model_single_output.png)

# %% [markdown]
# ### 5.2 Single input - Multiple output
#
# Here is an example of ConvNet with two output layers.
#
# ```python
# # Define the input layer
# X_input = layers.Input((28,28,1))
#
# # Stack the shared layers
# X = layers.Conv2D(8, (3,3), activation='relu')(X_input)
# X = layers.BatchNormalization()(X)
# X = layers.MaxPooling2D((2,2))(X)
#
# # Define the 1st head
# X_head1 = layers.Conv2D(16, (3,3), activation='relu')(X)
# X_head1 = layers.MaxPooling2D((2,2))(X_head1)
# X_head1 = layers.Flatten()(X_head1)
# X_head1 = layers.Dense(10, activation='softmax', name="Output_1")(X_head1) # output 1
#
# # Define the 2nd head
# X_head2 = layers.Conv2D(32, (5,5), activation='relu')(X)
# X_head2 = layers.MaxPooling2D((2,2))(X_head2)
# X_head2 = layers.Flatten()(X_head2)
# X_head2 = layers.Dense(4, activation='softmax', name="Output_2")(X_head2) # output 2
#
# # Create the multi-output model
# model = models.Model(inputs = X_input, outputs = [X_head1,X_head2])
# ```

# %% [markdown]
# The next figure shows a model with multiple outputs.
#
# ![model_multiple_output.png](attachment:model_multiple_output.png)

# %% [markdown]
# ## 6. Multi-Label vs Multi-Output
#
# In **multi-output** classification, the model provides a different output vector for each category in the training set. For example, the fashion dataset includes two categories with several sub-classes:
#
# - **Category 1** = Clothing type
#    - *Sub-class 1.1* = Jeans
#    - *Sub-class 1.2* = Shoes
#    - *Sub-class 1.3* = Dress
#    - *Sub-class 1.4* = Shirt
#
#
# - **Category 2** = Color
#    - *Sub-class 2.1* = Black
#    - *Sub-class 2.2* = Blue
#    - *Sub-class 2.3* = Red
#
# Hence, the network will have two output layers composed of 3 and 4 units, respectively. The mapping between the network outputs and the 7 sub-classes in the fashion dataset is as follows:
#
# - **Output layer 1** = Color
#   - Unit 1 = Black
#   - Unit 2 = Blue
#   - Unit 3 = Red
#
# - **Output layer 2** = Clothing type
#   - Unit 1 = Jeans
#   - Unit 2 = Dress
#   - Unit 3 = Shirt
#   - Unit 4 = Shoes
#
# The key difference here is that an item is always associated to two outputs. The cell below shows the one-hot encoded labels for the fashion dataset. Remark the difference with respect to the multi-label approach!

# %%
labels = np.array([key.split("_") for key, value in train_generator.class_indices.items()])

bin1 = LabelBinarizer()
bin2 = LabelBinarizer()

tag1 = bin1.fit_transform(labels[:,0])
tag2 = bin2.fit_transform(labels[:,1])

print(" color      cloth")
for i in range(len(labels)):
    print(tag1[i], "|", tag2[i], "-->", " ".join(labels[i]))

# %% [markdown]
# The following class extends the Keras generator, so as to produce the multi-output one-hot encoding.

# %%
from tensorflow.keras.utils import Sequence

class MultiOutputGenerator(Sequence):
    
    def __init__(self, generator):
        self.generator = generator
        self.classes = np.array([key for key, value in generator.class_indices.items()])
        labels = np.array([tag.split("_") for tag in self.classes])
        self.tag1 = LabelBinarizer()
        self.tag1.fit(labels[:,0])
        self.tag2 = LabelBinarizer()
        self.tag2.fit(labels[:,1])
                
    def __next__(self):
        batch_x, batch_y = self.generator.next()
        return batch_x, self.translate_labels(batch_y)

    def __getitem__(self, i):
        batch_x, batch_y = self.generator.__getitem__(i)
        return batch_x, self.translate_labels(batch_y)

    def __len__(self):
        return len(self.generator)

    def translate_labels(self, batch_y):
        idx = batch_y.argmax(axis=1)
        batch_y = self.classes[idx]
        batch_y = np.array([tag.split("_") for tag in batch_y])
        batch_y1 = self.tag1.transform(batch_y[:,0])
        batch_y2 = self.tag2.transform(batch_y[:,1])
        return [batch_y1, batch_y2]

# %% [markdown]
# The code below prepares the generators for multi-output classification.

# %%
train_generator_multioutput = MultiOutputGenerator(train_generator)
valid_generator_multioutput = MultiOutputGenerator(valid_generator)

# %% [markdown]
# ## 7. Multi-Output Classification
#
# **Exercise:** Build a ConvNet for multi-output classification. It must predict the 2 categories in the fashion dataset.
#
# - Define the architecture of your ConvNet.
#
# - Fit the ConvNet on the training set.
#
# - Evaluate its performance on the validation set.
#
# - Test your trained ConvNet on the images in the folder `fashion_examples`.
#
# **Tips:**
#
#  - Since you are dealing with *multi-output* classification, you end the network with two output layers, both having a `softmax` activation. The number of units in these last layer is equal to the number of sub-classes in each category to predict.
#
#
#  - For multi-output classification, the loss function is `categorical_crossentropy`.
#
#
#  - To visualize the layout of your ConvNet, you can use the function `plot_model()` as follows:
#  ```
#  utils.plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=False)
#  ```
#  This is particularly useful to debug the definition of your model. (*Note that you need to install the package "graphviz" to use this function.*)

# %%
# Define the network. Hint: use the functional API
model = ... # ADD CODE HERE

# Train the network. Hint: use .fit(...)
history = ... # ADD CODE HERE

# %%
# Get the training info
loss     = history.history['loss']
val_loss = history.history['val_loss']

# Visualize the history plots
plt.figure()
plt.plot(loss, 'b', label='Training loss')
plt.plot(val_loss, 'm', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# **Expected Output**:
#
# <table>
#     <tr>
#         <td>
#         </td>
#         <td>
#             Valid. accuracy
#         </td>
#     </tr>
#     <tr>
#         <td>
#             Color
#         </td>
#         <td>
#             around 99%
#         </td>
#     </tr>
#     <tr>
#         <td>
#             Type
#         </td>
#         <td>
#             around 97%
#         </td>
#     </tr>
# </table>

# %%
# Test the network
pred1, pred2 = model.predict(test_images)
color = pred1.argmax(axis=1)
cloth = pred2.argmax(axis=1)

# Get the multi-output categories
tag1 = train_generator_multioutput.tag1.inverse_transform(pred1)
tag2 = train_generator_multioutput.tag2.inverse_transform(pred2)

# Visualize the predictions
f, ax = plt.subplots(3, 3, figsize=(12,12))
for i, img in enumerate(test_images):
    ax.flat[i].imshow(img)
    ax.flat[i].axis("off")
    ax.flat[i].set_title(" ".join([tag1[i],tag2[i]]))  
plt.show()

# %% [markdown]
# Analyze the errors made by your ConvNet on the test images of never-seen-before clothing (black dress, red shoes, blue shoes):
#
# - Your ConvNet is able to correctly predict the color.
#
#
# - Depending on the architecture of your ConvNet, the prediction of the clothing type may still be wrong.

# %% [markdown]
# ## 7. Conclusion
#
# **Remember:** There are the four steps for building a neural network in Keras:
#  1. Stack the layers with the `Sequential` class or the functional API
#  - Compile the model
#  - Fit/Train
#  - Evaluate/Test
